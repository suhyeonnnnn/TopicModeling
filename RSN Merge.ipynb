# %% [markdown]
# # 시트별로 나누어져 있는 데이터를 합치기

# %%
import os
file_list = os.listdir('lucy/')
file_list
# Out:
# ['2019_1.xlsx',
#  '2019_10.xlsx',
#  '2019_100.xlsx',
#  '2019_102.xlsx',
#  '2019_103.xlsx',
#  '2019_104.xlsx',
#  '2019_105.xlsx',
#  '2019_106.xlsx',
#  '2019_107.xlsx',
#  '2019_108.xlsx',
#  '2019_109.xlsx',
#  '2019_11.xlsx',
#  '2019_110.xlsx',
#  '2019_111.xlsx',
#  '2019_112.xlsx',
#  '2019_113.xlsx',
#  '2019_114.xlsx',
#  '2019_115.xlsx',
#  '2019_116.xlsx',
#  '2019_117.xlsx',
#  '2019_118.xlsx',
#  '2019_119.xlsx',
#  '2019_12.xlsx',
#  '2019_120.xlsx',
#  '2019_121.xlsx',
#  '2019_122.xlsx',
#  '2019_123.xlsx',
#  '2019_124.xlsx',
#  '2019_125.xlsx',
#  '2019_126.xlsx',
#  '2019_127.xlsx',
#  '2019_128.xlsx',
#  '2019_129.xlsx',
#  '2019_13.xlsx',
#  '2019_130.xlsx',
#  '2019_132.xlsx',
#  '2019_133.xlsx',
#  '2019_134.xlsx',
#  '2019_136.xlsx',
#  '2019_137.xlsx',
#  '2019_138.xlsx',
#  '2019_139.xlsx',
#  '2019_14.xlsx',
#  '2019_140.xlsx',
#  '2019_141.xlsx',
#  '2019_142.xlsx',
#  '2019_143.xlsx',
#  '2019_144.xlsx',
#  '2019_147.xlsx',
#  '2019_148.xlsx',
# ...

# %%
os.chdir("C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC")
print(os.getcwd())
# /Users
# Out:
# C:\Users\sh921\Desktop\jupyter\game project\2020KMAC

# %%
import pandas as pd

for file in file_list:
    # 첫번째 시트를 읽어옵니다.
    df1 = pd.read_excel(file, sheet_name = '긍정')
    # 두번째 시트를 읽어옵니다.
    df2 = pd.read_excel(file, sheet_name = '부정')
    df3 = pd.read_excel(file, sheet_name = '중립')
    concatted_df = pd.concat([df1,df2,df3], axis=1)
    oncatted_df['gameCode'] = file 
    concatted_df.to_csv('file{}.csv'.format(file))

# %%
os.chdir("C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy20")
print(os.getcwd())
# Out:
# C:\Users\sh921\Desktop\jupyter\game project\2020KMAC\lucy\lucy20

# %%
file_list = os.listdir('C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy20')
file_list
# Out:
# ['102_1_샷온라인.xlsx',
#  '103_1_RF온라인.xlsx',
#  '104_1_워록.xlsx',
#  '105_1_한게임.xlsx',
#  '106_1_영웅온라인.xlsx',
#  '107_1_Sid.xlsx',
#  '108_1_War.xlsx',
#  '109_1_Football.xlsx',
#  '10_1_던파.xlsx',
#  '110_1_Sid.xlsx',
#  '111_1_라그나로크.xlsx',
#  '112_1_Dont.xlsx',
#  '113_1_한게임.xlsx',
#  '114_1_아틀란티카.xlsx',
#  '115_1_넷마블.xlsx',
#  '116_1_피망.xlsx',
#  '117_1_데카론.xlsx',
#  '118_1_미르의전설.xlsx',
#  '119_1_Team.xlsx',
#  '11_1_월드.xlsx',
#  '120_1_엠게임.xlsx',
#  '121_1_DK온라인.xlsx',
#  '122_1_Stardew.xlsx',
#  '123_1_테일즈.xlsx',
#  '124_1_넷마블.xlsx',
#  '125_1_십이지천2.xlsx',
#  '126_1_하운즈리로드.xlsx',
#  '127_1_건즈.xlsx',
#  '128_1_열혈강호.xlsx',
#  '129_1_한게임.xlsx',
#  '12_1_리니지.xlsx',
#  '130_1_엠게임.xlsx',
#  '132_1_크리티카.xlsx',
#  '133_1_출조낚시왕.xlsx',
#  '134_1_나이트.xlsx',
#  '135_1_한게임.xlsx',
#  '136_1_Hearts.xlsx',
#  '137_1_대항해시대.xlsx',
#  '139_1_붉은보석.xlsx',
#  '13_1_사이퍼즈.xlsx',
#  '140_1_엠게임.xlsx',
#  '141_1_뮤.xlsx',
#  '142_1_천상비.xlsx',
#  '143_1_Euro.xlsx',
#  '144_1_Total.xlsx',
#  '145_1_군주.xlsx',
# ...

# %%
import pandas as pd

for file in file_list:
    # 첫번째 시트를 읽어옵니다.
    df1 = pd.read_excel(file, sheet_name = '긍정')
    # 두번째 시트를 읽어옵니다.
    df2 = pd.read_excel(file, sheet_name = '부정')
    df3 = pd.read_excel(file, sheet_name = '중립')
    concatted_df = pd.concat([df1,df2,df3], axis=1)
    concatted_df['gameCode'] = file 
    concatted_df.to_csv('{}.csv'.format(file))

# %%
import os
file_list2 = os.listdir('C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy21')
file_list2
# Out:
# ['19071_20211003_ggg_1_1_lol.xlsx',
#  '19072_20211003_ggg_2_1_배그.xlsx',
#  '19073_20211003_ggg_3_1_피파4.xlsx',
#  '19074_20211003_ggg_4_1_옵치.xlsx',
#  '19075_20211003_ggg_5_1_로스트아크.xlsx',
#  '19076_20211003_ggg_6_1_메이플스토리.xlsx',
#  '19077_20211003_ggg_7_1_서든.xlsx',
#  '19078_20211003_ggg_8_1_카트.xlsx',
#  '19079_20211003_ggg_9_1_스타크래프트.xlsx',
#  '19081_20211003_ggg_10_1_던파.xlsx',
#  '19082_20211003_ggg_11_1_월드.xlsx',
#  '19083_20211003_ggg_12_1_리니지.xlsx',
#  '19084_20211003_ggg_13_1_사이퍼즈.xlsx',
#  '19085_20211003_ggg_14_1_Destiny.xlsx',
#  '19086_20211003_ggg_15_1_아이온.xlsx',
#  '19087_20211003_ggg_16_1_워크래프트3.xlsx',
#  '19090_20211003_ggg_17_1_레인보우식스.xlsx',
#  '19091_20211003_ggg_18_1_히어로즈.xlsx',
#  '19092_20211003_ggg_19_1_블레이드.xlsx',
#  '19093_20211003_ggg_20_1_테일즈런너.xlsx',
#  '19094_20211003_ggg_21_1_디아블로3.xlsx',
#  '19095_20211003_ggg_22_1_스타크래프트2.xlsx',
#  '19096_20211003_ggg_23_1_크레이지.xlsx',
#  '19097_20211003_ggg_24_1_검은사막.xlsx',
#  '19098_20211003_ggg_25_1_리니지2.xlsx',
# ...

# %%
os.chdir("C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy21")
print(os.getcwd())
# /Users
# Out:
# C:\Users\sh921\Desktop\jupyter\game project\2020KMAC\lucy\lucy21

# %%
import pandas as pd

for file in file_list2:
    # 첫번째 시트를 읽어옵니다.
    df1 = pd.read_excel(file, sheet_name = '긍정')
    # 두번째 시트를 읽어옵니다.
    df2 = pd.read_excel(file, sheet_name = '부정')
    df3 = pd.read_excel(file, sheet_name = '중립')
    concatted_df = pd.concat([df1,df2,df3], axis=1)
    concatted_df['gameCode'] = file 
    concatted_df.to_csv('file{}.csv'.format(file))

# %% [markdown]
# # 하나의 파일로 합치기

# %%
import os
file_list = os.listdir('C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy21')
file_list
# Out:
# ['file19071_20211003_ggg_1_1_lol.xlsx.csv',
#  'file19072_20211003_ggg_2_1_배그.xlsx.csv',
#  'file19073_20211003_ggg_3_1_피파4.xlsx.csv',
#  'file19074_20211003_ggg_4_1_옵치.xlsx.csv',
#  'file19075_20211003_ggg_5_1_로스트아크.xlsx.csv',
#  'file19076_20211003_ggg_6_1_메이플스토리.xlsx.csv',
#  'file19077_20211003_ggg_7_1_서든.xlsx.csv',
#  'file19078_20211003_ggg_8_1_카트.xlsx.csv',
#  'file19079_20211003_ggg_9_1_스타크래프트.xlsx.csv',
#  'file19081_20211003_ggg_10_1_던파.xlsx.csv',
#  'file19082_20211003_ggg_11_1_월드.xlsx.csv',
#  'file19083_20211003_ggg_12_1_리니지.xlsx.csv',
#  'file19084_20211003_ggg_13_1_사이퍼즈.xlsx.csv',
#  'file19085_20211003_ggg_14_1_Destiny.xlsx.csv',
#  'file19086_20211003_ggg_15_1_아이온.xlsx.csv',
#  'file19087_20211003_ggg_16_1_워크래프트3.xlsx.csv',
#  'file19090_20211003_ggg_17_1_레인보우식스.xlsx.csv',
#  'file19091_20211003_ggg_18_1_히어로즈.xlsx.csv',
#  'file19092_20211003_ggg_19_1_블레이드.xlsx.csv',
#  'file19093_20211003_ggg_20_1_테일즈런너.xlsx.csv',
#  'file19094_20211003_ggg_21_1_디아블로3.xlsx.csv',
# ...

# %%
df = []
for file in file_list:
    frame = pd.read_csv(file)
    df.append(frame)
    
master = pd.concat(df, ignore_index=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5224 entries, 0 to 5223
# Data columns (total 38 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  5224 non-null   int64
#  1   구분          5224 non-null   int64
#  2   블로그         5224 non-null   int64
#  3   카페          5224 non-null   int64
#  4   커뮤니티        5224 non-null   int64
#  5   언론          5224 non-null   int64
#  6   페이스북        5224 non-null   int64
#  7   인스타그램       5224 non-null   int64
#  8   카카오스토리      5224 non-null   int64
#  9   기업_단체       5224 non-null   int64
#  10  지식인         5224 non-null   int64
#  11  트위터         5224 non-null   int64
#  12  유투브         5224 non-null   int64
#  13  구분.1        5224 non-null   int64
#  14  블로그.1       5224 non-null   int64
#  15  카페.1        5224 non-null   int64
#  16  커뮤니티.1      5224 non-null   int64
#  17  언론.1        5224 non-null   int64
#  18  페이스북.1      5224 non-null   int64
# ...

# %%
import os
file_list = os.listdir('C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy20')
file_list
# Out:
# ['102_1_샷온라인.xlsx.csv',
#  '103_1_RF온라인.xlsx.csv',
#  '104_1_워록.xlsx.csv',
#  '105_1_한게임.xlsx.csv',
#  '106_1_영웅온라인.xlsx.csv',
#  '107_1_Sid.xlsx.csv',
#  '108_1_War.xlsx.csv',
#  '109_1_Football.xlsx.csv',
#  '10_1_던파.xlsx.csv',
#  '110_1_Sid.xlsx.csv',
#  '111_1_라그나로크.xlsx.csv',
#  '112_1_Dont.xlsx.csv',
#  '113_1_한게임.xlsx.csv',
#  '114_1_아틀란티카.xlsx.csv',
#  '115_1_넷마블.xlsx.csv',
#  '116_1_피망.xlsx.csv',
#  '117_1_데카론.xlsx.csv',
#  '118_1_미르의전설.xlsx.csv',
#  '119_1_Team.xlsx.csv',
#  '11_1_월드.xlsx.csv',
#  '120_1_엠게임.xlsx.csv',
#  '121_1_DK온라인.xlsx.csv',
#  '122_1_Stardew.xlsx.csv',
#  '123_1_테일즈.xlsx.csv',
#  '124_1_넷마블.xlsx.csv',
#  '125_1_십이지천2.xlsx.csv',
#  '126_1_하운즈리로드.xlsx.csv',
#  '127_1_건즈.xlsx.csv',
#  '128_1_열혈강호.xlsx.csv',
#  '129_1_한게임.xlsx.csv',
#  '12_1_리니지.xlsx.csv',
#  '130_1_엠게임.xlsx.csv',
#  '132_1_크리티카.xlsx.csv',
#  '133_1_출조낚시왕.xlsx.csv',
#  '134_1_나이트.xlsx.csv',
#  '135_1_한게임.xlsx.csv',
#  '136_1_Hearts.xlsx.csv',
#  '137_1_대항해시대.xlsx.csv',
# ...

# %%
os.chdir("C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy20")
print(os.getcwd())
# /Users
# Out:
# C:\Users\sh921\Desktop\jupyter\game project\2020KMAC\lucy\lucy20

# %%
df = []
for file in file_list:
    frame = pd.read_csv(file)
    df.append(frame)
    
master2 = pd.concat(df, ignore_index=True)

# %%
import os
file_list = os.listdir('C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy2019')
file_list
# Out:
# ['2019_1.csv',
#  '2019_10.csv',
#  '2019_100.csv',
#  '2019_102.csv',
#  '2019_103.csv',
#  '2019_104.csv',
#  '2019_105.csv',
#  '2019_106.csv',
#  '2019_107.csv',
#  '2019_108.csv',
#  '2019_109.csv',
#  '2019_11.csv',
#  '2019_110.csv',
#  '2019_111.csv',
#  '2019_112.csv',
#  '2019_113.csv',
#  '2019_114.csv',
#  '2019_115.csv',
#  '2019_116.csv',
#  '2019_117.csv',
#  '2019_118.csv',
#  '2019_119.csv',
#  '2019_12.csv',
#  '2019_120.csv',
#  '2019_121.csv',
#  '2019_122.csv',
#  '2019_123.csv',
#  '2019_124.csv',
#  '2019_125.csv',
#  '2019_126.csv',
#  '2019_127.csv',
#  '2019_128.csv',
#  '2019_129.csv',
#  '2019_13.csv',
#  '2019_130.csv',
#  '2019_132.csv',
#  '2019_133.csv',
#  '2019_134.csv',
#  '2019_136.csv',
#  '2019_137.csv',
#  '2019_138.csv',
#  '2019_139.csv',
#  '2019_14.csv',
#  '2019_140.csv',
#  '2019_141.csv',
#  '2019_142.csv',
#  '2019_143.csv',
#  '2019_144.csv',
#  '2019_147.csv',
#  '2019_148.csv',
#  '2019_149.csv',
#  '2019_15.csv',
#  '2019_150.csv',
# ...

# %%
os.chdir("C:\\Users\\sh921\\Desktop\\jupyter\\game project\\2020KMAC\\lucy\\lucy2019")
print(os.getcwd())
# /Users
# Out:
# C:\Users\sh921\Desktop\jupyter\game project\2020KMAC\lucy\lucy2019

# %%
df = []
for file in file_list:
    frame = pd.read_csv(file)
    df.append(frame)
    
master3 = pd.concat(df, ignore_index=True)

# %%
m = pd.concat([master,master2,master3], ignore_index=True)
m.head()
# Out:
#    Unnamed: 0        구분  블로그  카페  커뮤니티  언론  페이스북  인스타그램  카카오스토리  기업_단체  ...  \
# 0           0  20210101   49  53    16   0     0     36       1      2  ...
# 1           1  20210102   42  53    10  19     0     33       0      4  ...
# 2           2  20210103   73  34    19   8     0     31       0      5  ...
# 3           3  20210104   62  45    20  27     1     51       0      5  ...
# 4           4  20210105   57  33    12   3     3     49       0      9  ...
#
#    카카오스토리.2  기업_단체.2  지식인.2  트위터.2  유투브.2                         gameCode  \
# 0         0        4      1    249     22  19071_20211003_ggg_1_1_lol.xlsx
# 1         0        5      2    220     24  19071_20211003_ggg_1_1_lol.xlsx
# 2         0        5      4    310     16  19071_20211003_ggg_1_1_lol.xlsx
# 3         0        7      5    235     21  19071_20211003_ggg_1_1_lol.xlsx
# 4         0       14      7    296     16  19071_20211003_ggg_1_1_lol.xlsx
#
#    gamename  정부_공공  정부_공공.1  정부_공공.2
# ...

# %%
m
# Out:
#        Unnamed: 0        구분  블로그  카페  커뮤니티  언론  페이스북  인스타그램  카카오스토리  기업_단체  \
# 0               0  20210101   49  53    16   0     0     36       1      2
# 1               1  20210102   42  53    10  19     0     33       0      4
# 2               2  20210103   73  34    19   8     0     31       0      5
# 3               3  20210104   62  45    20  27     1     51       0      5
# 4               4  20210105   57  33    12   3     3     49       0      9
# ...           ...       ...  ...  ..   ...  ..   ...    ...     ...    ...
# 99158         361  20201227    0   0     0   0     0      0       0      0
# 99159         362  20201228    0   0     0   0     0      0       0      0
# 99160         363  20201229    0   0     0   0     0      0       0      0
# 99161         364  20201230    0   0     0   0     0      0       0      0
# 99162         365  20201231    0   0     0   0     0      0       0      0
#
#        ...  카카오스토리.2  기업_단체.2  지식인.2  트위터.2  유투브.2  \
# ...

# %%
m.to_csv("RSN_matser.csv")
