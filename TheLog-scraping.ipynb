# %%
import requests
from bs4 import BeautifulSoup

# %%
import time
from selenium import webdriver

import time
import pandas as pd

from selenium import webdriver
from bs4 import BeautifulSoup

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\sh921\anaconda3\lib\site-packages (from selenium) (1.26.4)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
ran = range(1,6)
url = "http://www.journalofadvertisingresearch.com/search/topic%252Bmodel?page=1&facet%5Bpublication-date%5D%5B0%5D=2017-2020"
url_list = []
for r in ran:
    url_list.append(url+str(r))
print(url_list)

datalist = []
for url in url_list:        
    req = requests.get(url)
    html = req.text
    soup = BeautifulSoup(html, 'html.parser')

    name = soup.select(
        'div > ol > li > article > h2 > span > a'
    )
    author = soup.select(
        'div > ol > li > article > div.author > div > span > span > a'  
    )
    
    journal = soup.select(
        'div > ol > li > article > span.journal-title'  
    )
    
    volume = soup.select(
        'div > ol > li > article > span.issue-meta-volume-issue'  
    )
    
    date = soup.select(
        'div > ol > li > article > span.publication-meta > span'  
    )
    
    
    for item in zip(name, author, journal, volume, date):
        datalist.append(
            {
                'name'      : item[0].text.replace('\n', '').replace('\t', '').replace('  ', ''),
                'author'  : item[1].text.replace('\n', '').replace('\t', '').replace('  ', ''),
                'journal'  : item[2].text.replace('\n', '').replace('\t', '').replace('  ', ''),
                'volume'  : item[3].text.replace('\n', '').replace('\t', '').replace('  ', ''),
                'date'  : item[4].text.replace('\n', '').replace('\t', '').replace('  ', ''),
                
                
            }
        )


data = pd.DataFrame(datalist)
data.to_csv('journallist3.csv')
# Out:
# ['http://www.journalofadvertisingresearch.com/search/topic%252Bmodel?page=1&facet%5Bpublication-date%5D%5B0%5D=2017-20201', 'http://www.journalofadvertisingresearch.com/search/topic%252Bmodel?page=1&facet%5Bpublication-date%5D%5B0%5D=2017-20202', 'http://www.journalofadvertisingresearch.com/search/topic%252Bmodel?page=1&facet%5Bpublication-date%5D%5B0%5D=2017-20203', 'http://www.journalofadvertisingresearch.com/search/topic%252Bmodel?page=1&facet%5Bpublication-date%5D%5B0%5D=2017-20204', 'http://www.journalofadvertisingresearch.com/search/topic%252Bmodel?page=1&facet%5Bpublication-date%5D%5B0%5D=2017-20205']

# %%
import requests
import re
import json

url = 'https://www.thelog.co.kr/api/service/getPressAreaTotalRank.do?menuType=0&gameType=&timeCode=opt1&stime=2021.09.09&etime=2021.09.09&page=1&gameDataType=A'
html = requests.get(url).text
print(html)
# Out:
# <!DOCTYPE HTML>
# <html>
# <head>
# 	<meta http-equiv="Expires" content="-1">
# 	<meta http-equiv="Pragma" content="no-cache">
# 	<meta http-equiv="Cache-Control" content="No-Cache">
#     <meta http-equiv="Content-Type" content="text/html; charset=ks_c_5601-1987">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
#     <meta name="google-site-verification" content="BquPyLqsvCIm-NoT3ZNQwH1sVmg47X3-ZI8dR8stV9s" />
#     <meta name="naver-site-verification" content="ed5fa3344f3752d296846c7de2bdc149ad94e9fc"/>
#     <meta property="og:type" content="website">
# 	<meta property="og:title" content="로그인 :: 더로그 (TheLog)">
# 	<meta property="og:description" content="더로그(TheLog)에 오신 것을 환영합니다. 로그인 하시면 보다 다양한 회원 서비스를 이용하실 수 있습니다.">
# 	<meta property="og:image" content="http://www.thelog.co.kr/images/common/h1_logo.png">
# 	<meta property="og:url" content="http://www.thelog.co.kr">
#     <title>The List of Games</title>
#     <link href="/css/common.css" rel="stylesheet" type="text/css"/>
#     <link href="/css/style.css" rel="stylesheet" type="text/css" />
#     <link rel="shortcut icon" type="image/x-icon" href="/images/favicon/favicon.ico">
#     <link href="/css/jquery-ui.min.css" rel="stylesheet" type="text/css" />
#     <link href="/css/jquery-ui.theme.min.css" rel="stylesheet" type="text/css" />
#     <link href="/css/jquery.comiseo.daterangepicker.css" rel="stylesheet" type="text/css" />
# 	<style>
# 		.textLimit {
# 			white-space: nowrap;
# 			overflow: hidden;
# 			text-overflow: ellipsis;
# 		}
# 	</style>
#     <script type="text/javascript" language="javascript" src="/js/jquery-1.12.4.min.js"></script>
#     <script type="text/javascript" language="javascript" src="/js/nmp-util-1.0.js?v=p2"></script>
#     <script type="text/javascript" language="javascript" src="/js/common.js?v=p2"></script>
# 	<script language="javascript" type="text/javascript" src="/js/util/keyboardUtil.js?v=p1"></script>
#     <!-- 하이차트 -->
#     <script language="javascript" type="text/javascript" src="/js/highcharts/highcharts.js"></script>
#     <script language="javascript" type="text/javascript" src="/js/highcharts/modules/exporting.js"></script>
#     <script type="text/javascript" src="/js/jquery-ui.min.js"></script>
#     <script type="text/javascript" src="/js/datepick/jquery.comiseo.daterangepicker.min.js"></script>
#     <script type="text/javascript" src="/js/datepick/moment.js"></script>
#
#     <script type="text/javascript">
#         $(function(){
#             // 리턴 정보 set
#             siteInfo.setReturnUrl('/stats/gameStats.do');
#             // 유저 찾기 등록
#             findUserInfo.init();
#             $("#id_save").change(function(){
#                 if($("#id_save").is(":checked")!=true){
#                     deleteCookie("id");
#                 }
#             });
#             $("#thelog_icon").click(function(){
#                 link.url("/index.do");
#             });
#         })
#
# 	    window.onpageshow = function(event) {
# 			if(event.persisted || (window.performance && window.performance.navigation.type == 2)) {
# 				if(getCookieValue("NW_THELOG_CERT") == "") {
# 					location.href = "/index.do";
# 				}
# 	    	}
# 		}
#     </script>
# </head>
# <body>
# <div id="wrap">
#     <div id="popup" title="알림">
#         <div id="popup_msg"></div>
#         <div id="popup_option"></div>
#     </div>
#     <!-- header-->
#     <header class="header_wrap"><!--is-active-->
#         <div id="header" class="clearfix">
#
#             <h1><img src="/images/common/h1_logo.png" alt="The Log" id="thelog_icon" style="cursor: pointer"/></h1>
#
#             <!-- gnb -->
#             <div class="gnb">
#                 <ul class="clearfix">
#                     <li><a href="javascript:void(0);" onclick="link.url('/info/about.do')" id="menu_about" class="gnb_meun">서비스 소개</a></li>
#                         <li><a href="javascript:void(0);" class="dep1 gnb_meun" id="menu_game_stats" onclick="loginCheck()">게임 통계</a>
#                             <ul class="dep2">
#                                 <li><a href="javascript:void(0);" onclick="loginCheck()" id="sub_menu_game_stats_time">Summary</a></li>
#                                 <li><a href="javascript:void(0);" onclick="loginCheck()" id="sub_menu_game_stats_time">전체게임순위</a></li>
#                                 <li><a href="javascript:void(0);" onclick="loginCheck()" id="sub_menu_game_stats_time">실시간</a></li>
#                                 <li><a href="javascript:void(0);" onclick="loginCheck()" id="sub_menu_game_stats_time">시간별</a></li>
#                                 <li><a href="javascript:void(0);" onclick="loginCheck()" id="sub_menu_game_stats_area">지역별</a></li>
#                             </ul>
#                         </li>
#                     <li><a href="javascript:void(0);" class="gnb_meun" id="menu_report" onclick="link.url('/report/reportList.do')">리포트</a>
#                     </li>
#                     <li><a href="javascript:void(0);" class="dep1 gnb_meun" id="menu_helpdesk" onclick="link.url('/helpdesk/notice/noticeList.do')">고객센터</a>
#                         <ul class="dep2">
#                             <li><a href="javascript:void(0);" onclick="link.url('/helpdesk/notice/noticeList.do')">공지사항</a></li>
#                             <li><a href="javascript:void(0);" onclick="link.url('/helpdesk/faq/faqList.do')">자주묻는 질문</a></li>
#                             <li><a href="javascript:void(0);" onclick="link.url('/helpdesk/terminfo/termInfoList.do')">용어정리</a></li>
#                                 <li><a href="javascript:void(0);" onclick="loginCheck()">1:1문의</a></li>
#                         </ul>
#                     </li>
#                 </ul>
#             </div>
#             <!-- //gnb -->
#             <!-- home_menu -->
#             <div class="gnb_home">
#                     <ul>
# 	                    <li><a href="#" class="login_btn">로그인</a></li>
# 	                    <li><a href="/member/signUp.do">회원가입</a></li>
#                     </ul>
#             </div>
#             <!-- //home_menu -->
#         </div>
#     </header>
#     <div class="screen"></div>
#     <!-- //header-->
# <script type="text/javascript">
#     $(function(){
#         // 로그인 form 에서 엔터창을 누를경우 이벤트 처리
#         $(document).on('keypress', ".loginbox", function(e) {
#             if (e.which == 13) {/* 13 == enter key@ascii */
#                 memberLogin();
#             }
#         });
#     });
# </script>
#
# <div class="container" style="width: 490px; min-height: 650px;">
#     <h1 class="gtitle"><span>로그인</span></h1><!--20190904수정-->
#     <p class="summ_mem" style="color: #888888;">The Log 서비스는 회원에게만 제공됩니다. <br/>아이디가 없으신 분들은 회원가입을 해주시기 바랍니다.</p>
#
#     <!-- 로그인 -->
#     <form>
#         <div class="loginbox">
#             <fieldset>
#                 <legend>로그인</legend>
#                 <input type="text" id="loginId" name="loginId" onfocus="" value="" style="ime-mode:disabled;" size="49"/>
#                 <input type="password" id="loginPasswd" name="loginPasswd"  value="" autocomplete="off" size="49" style="ime-mode: disabled"/>
#                 <div class="id_save"><label for="id_save" id="id_save_label">아이디저장<input type="checkbox" name="id_save" id="id_save"/></label></div>
#                 <ul class="idsearch clearfix">
#                     <li class="id"><a href="javascript:void(0);" onclick="findUserInfo.onBtnFindUserID();">아이디 찾기</a></li>
#                     <li class="pw"><a href="javascript:void(0);" onclick="findUserInfo.onBtnFindPW();">비밀번호 찾기</a></li>
#                 </ul>
#             </fieldset>
#
#                 <span class="btn_pack" style="display: block;"><input class="btn_login" type="button" onClick="memberLogin();" value="로그인"/></span>
#
#
#             <div>
#                 <!-- the log -->
#                 <ins class="adsbygoogle adbox"
#                      style="display:block;"
#                      data-ad-client="ca-pub-8149851036683088"
#                      data-ad-slot="5577842851">
#                     <a href="mailto:adby@nmp-corp.com"><img src="/images/member/login_banner.png"/></a>
#                 </ins>
#             </div>
#             <!-- //광고영역 -->
#
#             <!-- 광고영역 -->
#             <!--div>
#                 <script async src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#                 <ins class="adsbygoogle adbox"
#                      style="display:block;"
#                      data-ad-client="ca-pub-8149851036683088"
#                      data-ad-slot="5577842851"></ins>
#                 <script>
#                     (adsbygoogle = window.adsbygoogle || []).push({});
#                 </script>
#             </div-->
#             <!-- //광고영역 -->
#
#         </div>
#     </form>
#     <!-- //로그인 -->
# </div>
#
#     <!-- footer -->
#     <div id="footer">
#         <div class="f_menu">
#             <ul>
#                 <li><a href="/info/about.do">서비스소개</a></li>
#                 <li><a href="javascript:void(0);" onclick="openFooterPopup('/info/policy.do',1000,650)">이용약관</a></li>
#                 <li><a href="javascript:void(0);" onclick="openFooterPopup('/info/privacy.do',1000,650)"><b>개인정보처리방침</b></a></li>
#                 <li><a href="mailto:adby@nmp-corp.com">제휴문의</a></li>
#             </ul>
#         </div>
#         <div class="familysite">
#             <div>▼ Family Site</div>
#             <ul>
#                 <li><a href="http://www.nmp-corp.com" target="_blank">엔미디어플랫폼</a></li>
#                 <li><a href="http://www.geto.co.kr" target="_blank">게토</a></li>
#                 <li><a href="http://green.geto.co.kr" target="_blank">그린가드</a></li>
#                 <li><a href="http://www.adby.co.kr" target="_blank">애드바이</a></li>
#                 <li><a href="http://www.playgeto.com/landing/" target="_blank">플레이게토</a></li>
#                 <li><a href="http://www.studygeto.com" target="_blank">스터디게토</a></li>
#             </ul>
#         </div>
#         <div class="copyright">
#             <div>
#                 <em>상호 : (주)엔미디어플랫폼 &nbsp; | &nbsp; 대표자 : 송재화 &nbsp;<br/>주소 : 경기도 성남시 분당구 판교로 256번길 25(삼평동 631) GB2 B동 3층<br/>
#                     고객센터 : 1644-5910 &nbsp; | &nbsp; 사업자 등록번호 : 138-81-30598 &nbsp; | &nbsp; 통신판매등록번호 : 제2016-성남분당-0933호</em>
#                 ⓒ N Media Platform Co., LTD. ALL RIGHTS RESERVED.
#             </div>
#         </div>
# 	</div>
# 	<!-- //footer -->
# </div>
# </body>
# </html>
